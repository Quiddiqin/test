# %%
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
path = "https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/immobili.csv"

df = pd.read_csv(path)
df
# Out:
#         crim    zn  indus chas    nox     rm   age     dis  rad  tax ptratio  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2    4.09    1  296    15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671    2  242    17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671    2  242    17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622    3  222    18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622    3  222    18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ...  ...     ...
# 502  0.04527   0.0  11.93    0  0.573   6.12  76.7  2.2875    1  273    21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675    1  273    21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889    1  273    21.0
# 505  0.04741   0.0  11.93    0  0.573   6.03  80.8   2.505    1  273    21.0
# 506       is   not      a   ro     ck     et    sc      ie  nce    i      sn
#
#           b lstat  medv
# 0     396.9  4.98  24.0
# 1     396.9  9.14  21.6
# 2    392.83  4.03  34.7
# 3    394.63  2.94  33.4
# 4     396.9  5.33  36.2
# ..      ...   ...   ...
# 502   396.9  9.08  20.6
# 503   396.9  5.64  23.9
# 504  393.45  6.48  22.0
# 505   396.9  7.88  11.9
# 506      't    it     ?
#
# [507 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     507 non-null    object
#  1   zn       507 non-null    object
#  2   indus    507 non-null    object
#  3   chas     507 non-null    object
#  4   nox      507 non-null    object
#  5   rm       507 non-null    object
#  6   age      507 non-null    object
#  7   dis      507 non-null    object
#  8   rad      507 non-null    object
#  9   tax      507 non-null    object
#  10  ptratio  507 non-null    object
#  11  b        507 non-null    object
#  12  lstat    507 non-null    object
#  13  medv     507 non-null    object
# dtypes: object(14)
# memory usage: 55.6+ KB

# %%
df.rename( columns = {'medv' : 'price'}, inplace = True )

# %%
list(df)
# Out:
# ['crim',
#  'zn',
#  'indus',
#  'chas',
#  'nox',
#  'rm',
#  'age',
#  'dis',
#  'rad',
#  'tax',
#  'ptratio',
#  'b',
#  'lstat',
#  'price']

# %%
df.isnull().sum().sort_values()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
df['crim'].value_counts()
# Out:
# 0.01501    2
# 14.3337    2
# 0.00632    1
# 0.05083    1
# 0.03113    1
#           ..
# 2.24236    1
# 1.51902    1
# 1.83377    1
# 1.46336    1
# is         1
# Name: crim, Length: 505, dtype: int64

# %%
df.head(-1)
# Out:
#         crim    zn  indus chas    nox     rm   age     dis rad  tax ptratio  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2    4.09   1  296    15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242    17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242    17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222    18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222    18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ..  ...     ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786   1  273    21.0
# 502  0.04527   0.0  11.93    0  0.573   6.12  76.7  2.2875   1  273    21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675   1  273    21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889   1  273    21.0
# 505  0.04741   0.0  11.93    0  0.573   6.03  80.8   2.505   1  273    21.0
#
#           b lstat price
# 0     396.9  4.98  24.0
# 1     396.9  9.14  21.6
# 2    392.83  4.03  34.7
# 3    394.63  2.94  33.4
# 4     396.9  5.33  36.2
# ..      ...   ...   ...
# 501  391.99  9.67  22.4
# 502   396.9  9.08  20.6
# 503   396.9  5.64  23.9
# 504  393.45  6.48  22.0
# 505   396.9  7.88  11.9
#
# [506 rows x 14 columns]

# %%
df = df.head(-1)
df
# Out:
#         crim    zn  indus chas    nox     rm   age     dis rad  tax ptratio  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2    4.09   1  296    15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242    17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242    17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222    18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222    18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ..  ...     ...
# 500  0.22438   0.0   9.69    0  0.585  6.027  79.7  2.4982   6  391    19.2
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786   1  273    21.0
# 502  0.04527   0.0  11.93    0  0.573   6.12  76.7  2.2875   1  273    21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675   1  273    21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889   1  273    21.0
#
#           b  lstat price
# 0     396.9   4.98  24.0
# 1     396.9   9.14  21.6
# 2    392.83   4.03  34.7
# 3    394.63   2.94  33.4
# 4     396.9   5.33  36.2
# ..      ...    ...   ...
# 500   396.9  14.33  16.8
# 501  391.99   9.67  22.4
# 502   396.9   9.08  20.6
# 503   396.9   5.64  23.9
# 504  393.45   6.48  22.0
#
# [505 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    object
#  1   zn       506 non-null    object
#  2   indus    506 non-null    object
#  3   chas     506 non-null    object
#  4   nox      506 non-null    object
#  5   rm       506 non-null    object
#  6   age      506 non-null    object
#  7   dis      506 non-null    object
#  8   rad      506 non-null    object
#  9   tax      506 non-null    object
#  10  ptratio  506 non-null    object
#  11  b        506 non-null    object
#  12  lstat    506 non-null    object
#  13  price    506 non-null    object
# dtypes: object(14)
# memory usage: 55.5+ KB

# %%
df = df.astype('float')
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas       float64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad        float64
# tax        float64
# ptratio    float64
# b          float64
# lstat      float64
# price      float64
# dtype: object

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean     3.620585   11.386139   11.135208    0.069307    0.554659    6.285139
# std      8.608606   23.340080    6.867064    0.254227    0.115990    0.703222
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082210    0.000000    5.190000    0.000000    0.449000    5.885000
# 50%      0.259150    0.000000    9.690000    0.000000    0.538000    6.209000
# 75%      3.678220   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean    68.550693    3.797597    9.566337  408.504950   18.450495  356.594376
# std     28.171500    2.107013    8.707553  168.596437    2.164120   91.367787
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.000000    2.100000    4.000000  279.000000   17.400000  375.330000
# 50%     77.300000    3.215700    5.000000  330.000000   19.000000  391.430000
# 75%     94.100000    5.211900   24.000000  666.000000   20.200000  396.210000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat       price
# count  505.000000  505.000000
# mean    12.662515   22.553861
# std      7.144974    9.194008
# min      1.730000    5.000000
# 25%      6.930000   17.100000
# 50%     11.380000   21.200000
# 75%     16.960000   25.000000
# max     37.970000   50.000000

# %%
sns.pairplot(df, hue='price');

# %%
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200952  0.406753 -0.056129  0.421184 -0.219611  0.353218
# zn      -0.200952  1.000000 -0.533849 -0.042973 -0.516585  0.311754 -0.569358
# indus    0.406753 -0.533849  1.000000  0.063006  0.763644 -0.391649  0.644808
# chas    -0.056129 -0.042973  0.063006  1.000000  0.091297  0.091074  0.086775
# nox      0.421184 -0.516585  0.763644  0.091297  1.000000 -0.302121  0.731489
# rm      -0.219611  0.311754 -0.391649  0.091074 -0.302121  1.000000 -0.240029
# age      0.353218 -0.569358  0.644808  0.086775  0.731489 -0.240029  1.000000
# dis     -0.380381  0.664220 -0.708160 -0.099551 -0.769344  0.204909 -0.747771
# rad      0.625402 -0.313271  0.595933 -0.007907  0.612349 -0.210782  0.457392
# tax      0.582576 -0.315615  0.721415 -0.036046  0.668719 -0.292850  0.507566
# ptratio  0.291362 -0.391171  0.383509 -0.121055  0.188828 -0.355190  0.260909
# b       -0.384841  0.176022 -0.357151  0.049040 -0.380271  0.128427 -0.274018
# lstat    0.455351 -0.413922  0.604229 -0.054319  0.591365 -0.614641  0.603295
# price   -0.389839  0.359890 -0.484109  0.174880 -0.427536  0.695542 -0.376528
#
#               dis       rad       tax   ptratio         b     lstat     price
# crim    -0.380381  0.625402  0.582576  0.291362 -0.384841  0.455351 -0.389839
# zn       0.664220 -0.313271 -0.315615 -0.391171  0.176022 -0.413922  0.359890
# indus   -0.708160  0.595933  0.721415  0.383509 -0.357151  0.604229 -0.484109
# chas    -0.099551 -0.007907 -0.036046 -0.121055  0.049040 -0.054319  0.174880
# nox     -0.769344  0.612349  0.668719  0.188828 -0.380271  0.591365 -0.427536
# rm       0.204909 -0.210782 -0.292850 -0.355190  0.128427 -0.614641  0.695542
# age     -0.747771  0.457392  0.507566  0.260909 -0.274018  0.603295 -0.376528
# dis      1.000000 -0.496441 -0.535949 -0.231445  0.292212 -0.498215  0.248946
# rad     -0.496441  1.000000  0.910117  0.468120 -0.444065  0.488057 -0.384757
# tax     -0.535949  0.910117  1.000000  0.463656 -0.441474  0.543517 -0.471303
# ptratio -0.231445  0.468120  0.463656  1.000000 -0.178690  0.376286 -0.506456
# b        0.292212 -0.444065 -0.441474 -0.178690  1.000000 -0.365735  0.334980
# lstat   -0.498215  0.488057  0.543517  0.376286 -0.365735  1.000000 -0.740506
# price    0.248946 -0.384757 -0.471303 -0.506456  0.334980 -0.740506  1.000000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
X = df.drop(columns = 'price')
y = df['price']

# %%
X.ndim
# Out:
# 2

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                test_size = 0.2,
                                                random_state=667
                                                )

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-1.02044789e-01,  5.44048967e-02,  2.68898751e-02,  2.07000354e+00,
#        -1.42693456e+01,  3.71510532e+00, -1.68462577e-03, -1.53115834e+00,
#         2.79470272e-01, -1.34858757e-02, -8.00218170e-01,  9.10856486e-03,
#        -5.78056986e-01])

# %%
model.intercept_
# Out:
# 34.015691640739064

# %%
y_pred = model.predict(X_test)

# %%
length = y_pred.shape[0] 
x = np.linspace(0,length,length)


plt.figure(figsize=(30,15))
plt.plot(x, y_test, label='price reali')
plt.plot(x, y_pred, label='price predetti')
plt.legend(loc=2);

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

r2score = r2_score(y_test, y_pred)
r2score
# Out:
# 0.6625226311109719

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 3.7924533991161007

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 29.988164894067182

# %%
rmse = mean_squared_error(y_test, y_pred, squared=False)
rmse
# Out:
# 5.476145076061004

# %%
import joblib
joblib.dump(model, 'regression_test.pkl')
# Out:
# ['regression_test.pkl']
